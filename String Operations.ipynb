# %%
text = "Hello, World!"
print(text)
# Out:
# Hello, World!

# %%
#Length
text = "Python"
print("Length:", len(text))
# Out:
# Length: 6

# %%
#Uppercase
text = "Python Programming"
print(text.upper())
# Out:
# PYTHON PROGRAMMING

# %%
#Lowercase
text = "Python Programming"
print(text.lower())
# Out:
# python programming

# %%
#Reverse String
text = "Python"
print(text[::-1])
# Out:
# nohtyP

# %%
#Capitalize
text='sakshi'
print(text.capitalize())
# Out:
# Sakshi

# %%
#Title Case
text='sakshi bhingare'
print(text.title())
# Out:
# Sakshi Bhingare

# %%
sorted("pune")#arrange alphabetical order it is immutable so this returns list
# Out:
# ['e', 'n', 'p', 'u']

# %%
"".join(sorted("pune"))
# Out:
# 'enpu'

# %%
"".join(sorted("pune123"))#in that numbers can count ACICI code
# Out:
# '123enpu'

# %%
len("pune")#functions
# Out:
# 4

# %%
list("hello")
# Out:
# ['h', 'e', 'l', 'l', 'o']

# %%
"abc".isalpha()
# Out:
# True

# %%
"123".isdigit()
# Out:
# True

# %%
"abc123".isalnum()
# Out:
# True

# %%
"hello".startswith("he")
# Out:
# True

# %%
"hello".endswith("lo")
# Out:
# True

# %%
"banana".count("a")
# Out:
# 3
